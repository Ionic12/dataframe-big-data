# %%
import org.apache.spark.sql.{Dataset, SparkSession}
case class Dept(dept_id: Int, dept_name: String)
val deptRDD = sc.makeRDD(Seq(Dept(1,"Sales"),Dept(2,"HR")))
val deptDS = spark.createDataset(deptRDD)
val deptDF = spark.createDataFrame(deptRDD)
deptDS.rdd
deptDF.rdd
deptDS.filter(x => x.dept_location > 1).show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-0fa4bae1a382> in <module>
# ----> 1 from pyspark import *
#       2 from pyspark.sql import *
#       3 spark = SparkSession.builder.appName("metode1").getOrCreate()
#       4 sc = spark.sparkContext
#       5 mylist = [(50, "DataFrame"),(60, "pandas")]
#
# ModuleNotFoundError: No module named 'pyspark'
